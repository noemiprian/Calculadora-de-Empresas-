# %%
print("Cotizacion de Aire Acondicionado".center(120," "))
metros= int(input("¿Cuantos metros cuadrados es tu edificacion?: "))
if metros in range(1, 1001):
    True 
else: 
    raise KeyError("Acesam no cuenta con este rango, Necesitas contactarte con un vendedor")
    
def Cotizacion(equipo, marca):
    
    equipos = [ "mini SPLIT, 1TR",
               "mini SPLIT, 1.5TR","Unidad tipo paquete 5TR",
               "Unidad tipo paquete 10RT",
              "Unidad manejadora de aire 15-20iR"]

    equipos1 = {
        1: {"nombre": "mini SPLIT, 1TR",
            "precio_base": 1000},
        2: {"nombre": "mini SPLIT, 1.5TR",
           "precio_base": 8000},
        3: {"nombre":"Unidad tipo paquete 5TR",
           "precio_base": 15000},
        4: {"nombre":"Unidad tipo paquete 10RT",
           "precio_base": 20000},
        5: {"nombre":"Unidad manejadora de aire 15-20iR",
           "precio_base": 35000}
    }
    
    if marca == "LG":
        if equipo[0] == 0:
            return equipos1[1]["precio_base"] * 0.03 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    elif marca == "Trox":
        if equipo == 0:
            precio = equipos1[1]["precio_base"] * 0.05
            return precio
    elif marca == "Carrier":
        if equipo == 0:
            return equipos1[1]["precio_base"] * 0.08 
    elif marca == "Trane":
        if equipo == 0:
            return equipos1[1]["precio_base"] * 0.02
    elif marca == "York":
        if equipo == 0:
            return equipos1[1]["precio_base"] * 0.025
    elif marca == "LG":
        if equipo == 1:
            return equipos1[2]["precio_base"] * 0.1
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    elif marca == "Trox":
        if equipo == 1:
            return equipos1[2]["precio_base"] * 0.15
            
    elif marca == "Carrier":
        if equipo == 1:
            return equipos1[2]["precio_base"] * 0.1
    elif marca == "Trane":
        if equipo == 1:
            return equipos1[2]["precio_base"] * 0.17
    elif marca == "York":
        if equipo == 1:
            return equipos1[2]["precio_base"] * 0.2 
    elif marca == "LG":
        if equipo == 2:
            return equipos1[3]["precio_base"] * 0.13 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    elif marca == "Trox":
        if equipo == 2:
            return equipos1[3]["precio_base"] * 0.11 
            
    elif marca == "Carrier":
        if equipo == 2:
            return equipos1[3]["precio_base"] * 0.1 
    elif marca == "Trane":
        if equipo == 2:
            return equipos1[3]["precio_base"] * 0.25
    elif marca == "York":
        if equipo == 2:
            return equipos1[3]["precio_base"] * 0.075 
    elif marca == "LG":
        if equipo == 3:
            return equipos1[4]["precio_base"] * 0.2
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    elif marca == "Trox":
        if equipo == 3:
            return equipos1[4]["precio_base"]* 0.30
            
    elif marca == "Carrier":
        if equipo == 3:
            return equipos1[4]["precio_base"]*0.25
    elif marca == "Trane":
        if equipo == 3:
            return equipos1[4]["precio_base"] * 0.18
    elif marca == "York":
        if equipo == 3:
            return equipos1[4]["precio_base"] * 0.12 
    elif marca == "LG":
        if equipo == 3:
            return equipos1[5]["precio_base"] * 0.30 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    elif marca == "Trox":
        if equipo == 4:
            return equipos1[5]["precio_base"]* 0.25 
            
    elif marca == "Carrier":
        if equipo == 4:
            return equipos1[5]["precio_base"]*0.20
    elif marca == "Trane":
        if equipo == 4:
            return equipos1[5]["precio_base"] * 0.30
    elif marca == "York":
        if equipo == 4:
            return equipos1[5]["precio_base"] * 0.18
# Out:
#                                             Cotizacion de Aire Acondicionado
# ¿Cuantos metros cuadrados es tu edificacion?: 89

# %%
Cotizacion("mini SPLIT, 1TR", "Trox" )
