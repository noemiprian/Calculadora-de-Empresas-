# %%
print("Cotizacion de Aire Acondicionado".center(120," "))
Metros= input("¿Cuantos metros cuadrados es tu edificacion?: ")

Temperatura= input("¿Quieres solo enfriamiento o enfriamento y calefaccion?: ")
if Temperatura== "enfriamiento":
    True
elif Temperatura == "enfriamiento y calefaccion":
    True
else:
    raise KeyError("Asesam no cuenta con equipos de esa temperatura")

    equipos = [ "mini SPLIT, 1TR",
               "mini SPLIT, 1.5TR","Unidad tipo paquete 5TR",
               "Unidad tipo paquete 10RT",
              "Unidad manejadora de aire 15-20iR"]
    if equipo in equipos:
        True
def Cotizacion(marca):
    equipos = {
        1: {"nombre": "mini SPLIT, 1TR",
            "precio_base": 1000},
        2: {"nombre": "mini SPLIT, 1.5TR",
           "precio_base": 8000},
        3: {"nombre":"Unidad tipo paquete 5TR",
           "precio_base": 15000},
        4: {"nombre":"Unidad tipo paquete 10RT",
           "precio_base": 20000},
        5: {"nombre":"Unidad manejadora de aire 15-20iR",
           "precio_base": 35000}
    }
    
    if marca == "LG":
        if equipo == 1:
            return equipos[1]["precio_base"] * 0.03 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    if marca == "Trox":
        if equipo == 1:
            return equipos[1]["precio_base"] * 0.05 
    if marca == "Carrier":
        if equipo == 1:
            return equipos[1]["precio_base"] * 0.08 
    if marca == "Trane":
        if equipo == 1:
            return equipos[1]["precio_base"] * 0.02
    if marca == "York":
        if equipo == 1:
            return equipos[1]["precio_base"] * 0.025 
    if marca == "LG":
        if equipo == 2:
            return equipos[2]["precio_base"] * 0.1
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    if marca == "Trox":
        if equipo == 2:
            return equipos[2]["precio_base"] * 0.15
            
    if marca == "Carrier":
        if equipo == 2:
            return equipos[2]["precio_base"] * 0.1
    if marca == "Trane":
        if equipo == 2:
            return equipos[2]["precio_base"] * 0.17
    if marca == "York":
        if equipo == 2:
            return equipos[2]["precio_base"] * 0.2 
    if marca == "LG":
        if equipo == 3:
            return equipos[3]["precio_base"] * 0.13 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    if marca == "Trox":
        if equipo == 3:
            return equipos[3]["precio_base"] * 0.11 
            
    if marca == "Carrier":
        if equipo == 3:
            return equipos[3]["precio_base"] * 0.1 
    if marca == "Trane":
        if equipo == 3:
            return equipos[3]["precio_base"] * 0.25
    if marca == "York":
        if equipo == 3:
            return equipos[3]["precio_base"] * 0.075 
    if marca == "LG":
        if equipo == 4:
            return equipos[4]["precio_base"] * 0.2
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    if marca == "Trox":
        if equipo == 4:
            return equipos[4]["precio_base"]* 0.30
            
    if marca == "Carrier":
        if equipo == 4:
            return equipos[4]["precio_base"]*0.25
    if marca == "Trane":
        if equipo == 4:
            return equipos[4]["precio_base"] * 0.18
    if marca == "York":
        if equipo == 4:
            return equipos[4]["precio_base"] * 0.12 
    if marca == "LG":
        if equipo == 5:
            return equipos[5]["precio_base"] * 0.30 
        else:
            raise KeyError("La marca para este equipo no esta disponible")
    if marca == "Trox":
        if equipo == 5:
            return equipos[5]["precio_base"]* 0.25 
            
    if marca == "Carrier":
        if equipo == 5:
            return equipos[5]["precio_base"]*0.20
    if marca == "Trane":
        if equipo == 5:
            return equipos[5]["precio_base"] * 0.30
    if marca == "York":
        if equipo == 5:
            return equipos[5]["precio_base"] * 0.18
